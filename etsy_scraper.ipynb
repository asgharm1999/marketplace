# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
fout = open('Etsy.txt', 'wt',encoding='utf-8')

# %%
fclean = open('Etsy_clean.txt', 'wt')

# %%
search_results = []
page = 1
titles = []

while page < 3:
    url = f"https://www.etsy.com/search?q=dining+table+and+chairs&ref=auto-1&as_prefix=dining+table+and+chairs&page={page}"
    response=requests.get(url,headers=headers)
    soup=BeautifulSoup(response.content,'html')
    fout.write(str(soup))
    for item in soup.select('.wt-grid__item-xs-6'): 
        try: 
            print('-------------------------')
            #print(item)
            title = item.select('h3')[0].get_text().strip()
            print(title)
            fclean.write('title')
            price=item.select('.currency-value')[0].get_text().strip()
            print(price)
            fclean.write(price)
            rating=item.find("input", {'name': "rating"}).attrs['value']
            print(rating)
            fclean.write(rating)
            link = item.find("a", {'class': "listing-link wt-display-inline-block bbc3092379125a8bb"}).attrs['href']
            if(link is None):
                link = 'Missing'
            print(link)
            search_results.append([title, price, rating,link])
        except Exception as e: 
                #raise e 
                b=0  
    page = page+1
    

columns = ('Title', 'Price', 'Rating','Link')
df = pd.DataFrame(search_results, columns=columns)
# Out:
# -------------------------
# The Hannah | Dining Table | Farmhouse Kitchen Table Set | Dining Table or Dining Set with Stools or Benches
# 469.00
# 4.9493
# https://www.etsy.com/listing/1234084375/the-hannah-dining-table-farmhouse?click_key=5890fd340c3db9151e5ed32cc6f8c92369970cba%3A1234084375&click_sum=3a363aa5&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-1-1&frs=1&sts=1
# -------------------------
# ...Distressed Dining Table with Rebar Hairpin Legs with Live Edges
# 229.00
# 4.8326
# https://www.etsy.com/listing/1228338124/clearance-sale-alive-edge-reclaimed?click_key=66671806cc1d7bf9d6d25e48337bff6d30b69dbc%3A1228338124&click_sum=7c9eea90&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-1-2&pro=1&frs=1&sts=1
# -------------------------
# Custom Walnut Dining Table and Chair Set, Live Edge Kitchen Table, Living Room Chairs Set, Walnut Dining Table, Express Free Shipping.
# 1,375.00
# 4.4286
# https://www.etsy.com/listing/1173176018/custom-walnut-dining-table-and-chair-set?click_key=680b8b31dd6ad1dbd39eca1ad2b7c596bde8502a%3A1173176018&click_sum=d2eb974c&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-1-3&pro=1&frs=1
# -------------------------
# Dining Table Chair - Wooden Legs and Back - Mid-Century Modern Chair - Handmade Wooden Dining Chair - Chairs for Dining Room
# 269.00
# 4.5517
# https://www.etsy.com/listing/1201644936/dining-table-chair-wooden-legs-and-back?click_key=40c2456eb9193103a8744fc8014645a97d56d7f5%3A1201644936&click_sum=79765fcb&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-1-4&frs=1
# -------------------------
# Farm Table, Farmhouse Table, Trestle Table, Dine Room Table, Dine Table, Rustic, Furniture, Vintage, Farmhouse Table, Farm
# 1,097.17
# 4.9106
# -------------------------
# Modern Wood Dining Table
# 490.00
# 4.8944
# -------------------------
# Live-Edge Solid Wood Dining Table
# 560.00
# 4.8944
# -------------------------
# Live Edge Dining Table - Teak Wood Dining Room Table
# 560.00
# 4.8944
# -------------------------
# Mid Century Modern  Extending Dining Table  for 6 People Wood Kitchen Table - Breakfast Table Butterfly Mechanism
# 699.99
# 4.7094
# -------------------------
# Farmhouse Wood Dining Table - Rustic Wood Dining Table
# 459.50
# 4.8944
# -------------------------
# Solid Wood Table and Bench - High Quality / Rustic Dining Table / Wood Kitchen Table with Metal Legs / Farmhouse Dine Table / Writing Desk
# 882.35
# 4.8689
# -------------------------
# Dining Table Set | Custom Dining Table | Dining Table Set | Dining Table And Chairs | Dine Table | Dining Chairs | Dine Table Set
# 607.50
# 4.52
# -------------------------
# -------------------------
# -------------------------
# Winchester Red Oak Table, Four 'San Remo' Chairs, Stanley Refinished Hutch & Server | Beach | Coastal
# 6,800.00
# 4.6
# https://www.etsy.com/listing/1214541858/winchester-red-oak-table-four-san-remo?click_key=15218e5fe1f79bc0e783560158c247669ca88a98%3A1214541858&click_sum=5abb84b9&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-2-1&pro=1&frs=1
# -------------------------
# The Westley | Dining Table | Kitchen Table Set | Farmhouse Style | Small Kitchen Table
# 549.00
# 4.9493
# https://www.etsy.com/listing/776117101/the-westley-dining-table-kitchen-table?click_key=6895218810fddd1c6c876dc545d7dc2d19a8e39a%3A776117101&click_sum=cefcc7fc&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-2-2&frs=1&sts=1
# -------------------------
# Clearance Sale! Reclaimed Distressed Round Dining Table. Heavy Duty Iron Pipe legs. Choose size and height.
# 289.60
# 4.8326
# https://www.etsy.com/listing/699394312/clearance-sale-reclaimed-distressed?click_key=9dbf03f9ec55852cf7480dc25bee58ba0439632c%3A699394312&click_sum=8eda8b89&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-2-3&pro=1&frs=1&sts=1
# -------------------------
# 5 Pieces Dining Set 4 Chairs and 47" Dining Table, Mid Century Modern Solid Wood Dining Set, Kitchen Dining Table, Rectangular Table
# 499.00
# 4.5517
# https://www.etsy.com/listing/1263089941/5-pieces-dining-set-4-chairs-and-47?click_key=7bbc63940e04f4c281b6fd90c11d99c03f9d0200%3A1263089941&click_sum=d3e2c1a2&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=dining+table+and+chairs&ref=listing_in_grid-2-4&frs=1
# -------------------------
# Standing Desk - South American Walnut, Modern, Live Edge Desk, Adjustable Desk, Office Desk, Sit Stand Desk, Stand Up Desk, Computer Desk
# 389.40
# 4.9009
# -------------------------
# TableChamp Dining Room Chairs Solid Wood Pine - 10 Different Colors - Set of 2 Pieces
# 189.00
# 5
# -------------------------
# Farmhouse Table Plans(with pictures)
# 2.00
# 4.6765
# -------------------------
# Live Edge Dining Room Table - Solid Wood Table | Farm Table | Conference Table | Large Dining Table | Restaurant Table | Acacia Wood
# 1,700.00
# 4.9091
# -------------------------
# Farm Table, Farmhouse Table, Trestle Table, Dine Room Table, Dine Table, Rustic, Furniture, Vintage, Farmhouse Table, Farm
# 841.49
# 4.8864
# -------------------------
# Nesting Weaning Table - Solid Cherry Hardwood - Cube Weaning Table - Montessori Weaning Table and Chair - Dining - Eating - Kitchen
# 139.50
# 4.975
# -------------------------
# Round Farmhouse Breakfast Table SALE Mixed Barn Wood and Metal Pedestal Kitchen Nook/Dining Room Furniture, 30" 36" (3') 42" 48" (4') top
# 289.00
# 4.8097
# -------------------------
# Round Dining Table. Handmade with Rustic Reclaimed Wood. Industrial Steel Hairpin Legs. Available to Ship Worldwide.
# 177.59
# 4.9002
# -------------------------
# -------------------------

# %%
df
# Out:
#                                                Title     Price  Rating  \
# 0  The Hannah | Dining Table | Farmhouse Kitchen ...    469.00  4.9493
# 1  ...Distressed Dining Table with Rebar Hairpin ...    229.00  4.8326
# 2  Custom Walnut Dining Table and Chair Set, Live...  1,375.00  4.4286
# 3  Dining Table Chair - Wooden Legs and Back - Mi...    269.00  4.5517
# 4  Winchester Red Oak Table, Four 'San Remo' Chai...  6,800.00     4.6
# 5  The Westley | Dining Table | Kitchen Table Set...    549.00  4.9493
# 6  Clearance Sale! Reclaimed Distressed Round Din...    289.60  4.8326
# 7  5 Pieces Dining Set 4 Chairs and 47" Dining Ta...    499.00  4.5517
#
#                                                 Link
# 0  https://www.etsy.com/listing/1234084375/the-ha...
# 1  https://www.etsy.com/listing/1228338124/cleara...
# 2  https://www.etsy.com/listing/1173176018/custom...
# 3  https://www.etsy.com/listing/1201644936/dining...
# 4  https://www.etsy.com/listing/1214541858/winche...
# 5  https://www.etsy.com/listing/776117101/the-wes...
# 6  https://www.etsy.com/listing/699394312/clearan...
# 7  https://www.etsy.com/listing/1263089941/5-piec...

# %%
df.to_csv('Etsy_clean.csv')

# %%
fout.close()
fclean.close()
