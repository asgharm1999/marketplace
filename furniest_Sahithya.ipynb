# %%
# !pip install apify
# Out:
# Collecting apify
#   Downloading apify-0.0.2-py3-none-any.whl (5.6 kB)
# Installing collected packages: apify
# Successfully installed apify-0.0.2

# %%
import pandas as pd
import numpy as np
import datetime
from bs4 import BeautifulSoup
import urllib3
import requests
import time
import re
import os
import math

# %%
base_url = "https://www.realsimple.com/home-organizing/decorating"

page = requests.get(base_url)
data=[]

# %%
response = requests.get(base_url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="comp no-js taxlevel-2 taxlevel-2 taxonomyScTemplate html mntl-html" data-ab="60,99,99,99,99" data-mantle-resource-version="3.13.441" data-realsimple-resource-version="1.10.0" data-resource-version="1.10.0" data-tracking-container="true" id="taxonomyScTemplate_1-0" lang="en">
#  <!--
# <globe-environment environment="k8s-prod" application="realsimple" dataCenter="us-east-1"/>
# -->
#  <head class="loc head">
#   <script type="text/javascript">
#    var Mntl = window.Mntl || {};
#   </script>
#   <link href="//js-sec.indexww.com" rel="preconnect"/>
#   <link href="//c.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//tags.crwdcntrl.net" rel="preconnect"/>
#   <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="max-image-preview:large, NOODP, NOYDIR" name="robots">
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <link href="https://www.realsimple.com/home-organizing/decorating" rel="canonical">
#     <title>
#      Decorating Ideas for Every Room in Your House | Real Simple
#     </title>
#     <meta content="Whether you're looking for living room decorating ideas or the trendiest paint colors, you've come to the right place. Here's how to decorate a beautiful home." itemprop="description" name="description"/>
#     <meta content="REALSIMPLE" name="emailvertical">
#      <meta content="Real Simple Editors" name="sailthru.author">
#       <meta content="home-organizing,home-organizing-decorating" name="sailthru.tags">
#        <!-- Pinterest Pins -->
#        <meta content="Decorating" itemprop="name"/>
#        <meta content="Real Simple" property="article:section"/>
#        <!-- Facebook Open Graph Tags -->
#        <meta content="165082593548215" property="fb:app_id"/>
#        <meta content="article" property="og:type"/>
#        <meta content="Real Simple" property="og:site_name"/>
#        <meta content="https://www.realsimple.com/home-organizing/decorating" property="og:url"/>
#        <meta content="Decorating" property="og:title"/>
#        <meta content="Whether you're looking for living room decorating ideas or the trendiest paint colors, you've come to the right place. Here's how to decorate a beautiful home." property="og:description"/>
#        <meta content="https://www.realsimple.com/thmb/osZEJWn_le7gylKjF3Kezy9DDQE=/2000x500/filters:fill(auto,1)/decorating-banner-2000-026f9d1b9f9f44a2a9a9b2570bf27261.jpg" property="og:image"/>
#        <meta content="false" property="article:opinion"/>
#        <meta content="https://www.facebook.com/realsimple/" property="article:author"/>
#        <!-- Twitter Cards -->
#        <meta content="summary_large_image" name="twitter:card"/>
#        <meta content="@realsimple" name="twitter:site"/>
#        <meta content="Decorating" name="twitter:title"/>
#        <meta content="Whether you're looking for living room decorating ideas or the trendiest paint colors, you've come to the right place. Here's how to decorate a beautiful home." name="twitter:description"/>
#        <meta content="https://www.realsimple.com/thmb/osZEJWn_le7gylKjF3Kezy9DDQE=/2000x500/filters:fill(auto,1)/decorating-banner-2000-026f9d1b9f9f44a2a9a9b2570bf27261.jpg" name="twitter:image"/>
#        <link data-glb-css="" href="/static/1.10.0/cache/eNqdVVuSrCAM3dClXMT8ziYiRKUGSBfB7pndXx5Oqy2N1nwIBHLygJPYcYCgZWfBBYOdZO7SDv7rjgfawojiZkDiREahfyqlUwvaHVBkb-TQBe5AcVa7a4W0AvcK8WuYeGg1Ypwn1OMUPiZwI35qDujQVzcbtgJ8kyP7wyX4VayG5uNGxC-zkOSi_ZBQIhoo01-ciQlhd48rhlEGTa6i3cAfXXPwswyzR_WMOj9jGRvAopXCHfXQ0HNw1yOkULvex2ikn21fnnoj1zJ8g6yhLuWVuStFm0MV3BSsycOlZxCOFL6KF0jLJDUYwRP4cq02aortbs19FX0GWmOePMaCJQ6bZSNWCV4JE4tnXdXsp8O2ct10Ht6VvslM7mmrUu8iLp7dN3dY5D-VH-veaDeePuJ7C78t4d1djYZ6MB1_6ZsI9OTci9xALjX_vlFsymgO2ugQOQn37bqGGsjb6CN1yUQlBC-nF7HFR4vM6WfQg0vNdy-eRFlSyUGuyxPMMBvDMlLYZdxePMEu5TKQMfTYSxf-V4PB78gSPOkrv-o1Gh8fdSAK8drKdJZ6VippP5fXMJHbX7wTrjVyRUEBT2J2sbA8g8neU3rVk_NEz6HHeFR8JhqXqeHC4YMNhpTiAjns_AcIyG53.min.css" rel="stylesheet" type="text/css"/>
#        <style type="text/css">
#         #onetrust-banner-sdk{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}#onetrust-banner-sdk .onetrust-vendors-list-handler{cursor:pointer;color:#1f96db;font-size:inherit;font-weight:bold;text-decoration:none;margin-left:5px}#onetrust-banner-sdk .onetrust-vendors-list-handler:hover{color:#1f96db}#onetrust-banner-sdk:focus{outline:2px solid #000;outline-offset:-2px}#onetrust-banner-sdk a:focus{outline:2px solid #000}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{outline-offset:1px}#onetrust-banner-sdk .ot-close-icon,#onetrust-pc-sdk .ot-close-icon,#ot-sync-ntfy .ot-close-icon{background-image:url("data:image/svg+xml;base64,...");background-size:contain;background-repeat:no-repeat;background-position:center;height:12px;width:12px}#onetrust-banner-sdk .powered-by-logo,#onetrust-banner-sdk .ot-pc-footer-logo a,#onetrust-pc-sdk .powered-by-logo,#onetrust-pc-sdk .ot-pc-footer-logo a,#ot-sync-ntfy .powered-by-logo,#ot-sync-ntfy .ot-pc-footer-logo a{background-size:contain;background-repeat:no-repeat;background-position:center;height:25px;width:152px;display:block}#onetrust-banner-sdk h3 *,#onetrust-banner-sdk h4 *,#onetrust-banner-sdk h6 *,#onetrust-banner-sdk button *,#onetrust-banner-sdk a[data-parent-id] *,#onetrust-pc-sdk h3 *,#onetrust-pc-sdk h4 *,#onetrust-pc-sdk h6 *,#onetrust-pc-sdk button *,#onetrust-pc-sdk a[data-parent-id] *,#ot-sync-ntfy h3 *,#ot-sync-ntfy h4 *,#ot-sync-ntfy h6 *,#ot-sync-ntfy button *,#ot-sync-ntfy a[data-parent-id] *{font-size:inherit;font-weight:inherit;color:inherit}#onetrust-banner-sdk .ot-hide,#onetrust-pc-sdk .ot-hide,#ot-sync-ntfy .ot-hide{display:none !important}#onetrust-pc-sdk .ot-sdk-row .ot-sdk-column{padding:0}#onetrust-pc-sdk .ot-sdk-container{padding-right:0}#onetrust-pc-sdk .ot-sdk-row{flex-direction:initial;width:100%}#onetrust-pc-sdk [type="checkbox"]:checked,#onetrust-pc-sdk [type="checkbox"]:not(:checked){pointer-events:initial}#onetrust-pc-sdk [type="checkbox"]:disabled+label::before,#onetrust-pc-sdk [type="checkbox"]:disabled+label:after,#onetrust-pc-sdk [type="checkbox"]:disabled+label{pointer-events:none;opacity:0.7}#onetrust-pc-sdk #vendor-list-content{transform:translate3d(0, 0, 0)}#onetrust-pc-sdk li input[type="checkbox"]{z-index:1}#onetrust-pc-sdk li .ot-checkbox label{z-index:2}#onetrust-pc-sdk li .ot-checkbox input[type="checkbox"]{height:auto;width:auto}#onetrust-pc-sdk li .host-title a,#onetrust-pc-sdk li .ot-host-name a,#onetrust-pc-sdk li .accordion-text,#onetrust-pc-sdk li .ot-acc-txt{z-index:2;position:relative}#onetrust-pc-sdk input{margin:3px 0.1ex}#onetrust-pc-sdk .pc-logo,#onetrust-pc-sdk .ot-pc-logo{height:60px;width:180px;background-position:center;background-size:contain;background-repeat:no-repeat}#onetrust-pc-sdk .screen-reader-only,#onetrust-pc-sdk .ot-scrn-rdr,.ot-sdk-cookie-policy .screen-reader-only,.ot-sdk-cookie-policy .ot-scrn-rdr{border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px}#onetrust-pc-sdk.ot-fade-in,.onetrust-pc-dark-filter.ot-fade-in,#onetrust-banner-sdk.ot-fade-in{animation-name:onetrust-fade-in;animation-duration:400ms;animation-timing-function:ease-in-out}#onetrust-pc-sdk.ot-hide{display:none !important}.onetrust-pc-dark-filter.ot-hide{display:none !important}#ot-sdk-btn.ot-sdk-show-settings,#ot-sdk-btn.optanon-show-settings{color:#68b631;border:1px solid #68b631;height:auto;white-space:normal;word-wrap:break-word;padding:0.8em 2em;font-size:0.8em;line-height:1.2;cursor:pointer;-moz-transition:0.1s ease;-o-transition:0.1s ease;-webkit-transition:1s ease;transition:0.1s ease}#ot-sdk-btn.ot-sdk-show-settings:hover,#ot-sdk-btn.optanon-show-settings:hover{color:#fff;background-color:#68b631}.onetrust-pc-dark-filter{background:rgba(0,0,0,0.5);z-index:2147483646;width:100%;height:100%;overflow:hidden;position:fixed;top:0;bottom:0;left:0}@keyframes onetrust-fade-in{0%{opacity:0}100%{ ...
# #onetrust-banner-sdk,#onetrust-pc-sdk,#ot-sdk-cookie-policy,#ot-sync-ntfy{font-size:16px}#onetrust-banner-sdk *,#onetrust-banner-sdk ::after,#onetrust-banner-sdk ::before,#onetrust-pc-sdk *,#onetrust-pc-sdk ::after,#onetrust-pc-sdk ::before,#ot-sdk-cookie-policy *,#ot-sdk-cookie-policy ::after,#ot-sdk-cookie-policy ::before,#ot-sync-ntfy *,#ot-sync-ntfy ::after,#ot-sync-ntfy ::before{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}#onetrust-banner-sdk div,#onetrust-banner-sdk span,#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-banner-sdk p,#onetrust-banner-sdk img,#onetrust-banner-sdk svg,#onetrust-banner-sdk button,#onetrust-banner-sdk section,#onetrust-banner-sdk a,#onetrust-banner-sdk label,#onetrust-banner-sdk input,#onetrust-banner-sdk ul,#onetrust-banner-sdk li,#onetrust-banner-sdk nav,#onetrust-banner-sdk table,#onetrust-banner-sdk thead,#onetrust-banner-sdk tr,#onetrust-banner-sdk td,#onetrust-banner-sdk tbody,#onetrust-banner-sdk .ot-main-content,#onetrust-banner-sdk .ot-toggle,#onetrust-banner-sdk #ot-content,#onetrust-banner-sdk #ot-pc-content,#onetrust-banner-sdk .checkbox,#onetrust-pc-sdk div,#onetrust-pc-sdk span,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#onetrust-pc-sdk p,#onetrust-pc-sdk img,#onetrust-pc-sdk svg,#onetrust-pc-sdk button,#onetrust-pc-sdk section,#onetrust-pc-sdk a,#onetrust-pc-sdk label,#onetrust-pc-sdk input,#onetrust-pc-sdk ul,#onetrust-pc-sdk li,#onetrust-pc-sdk nav,#onetrust-pc-sdk table,#onetrust-pc-sdk thead,#onetrust-pc-sdk tr,#onetrust-pc-sdk td,#onetrust-pc-sdk tbody,#onetrust-pc-sdk .ot-main-content,#onetrust-pc-sdk .ot-toggle,#onetrust-pc-sdk #ot-content,#onetrust-pc-sdk #ot-pc-content,#onetrust-pc-sdk .checkbox,#ot-sdk-cookie-policy div,#ot-sdk-cookie-policy span,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy p,#ot-sdk-cookie-policy img,#ot-sdk-cookie-policy svg,#ot-sdk-cookie-policy button,#ot-sdk-cookie-policy section,#ot-sdk-cookie-policy a,#ot-sdk-cookie-policy label,#ot-sdk-cookie-policy input,#ot-sdk-cookie-policy ul,#ot-sdk-cookie-policy li,#ot-sdk-cookie-policy nav,#ot-sdk-cookie-policy table,#ot-sdk-cookie-policy thead,#ot-sdk-cookie-policy tr,#ot-sdk-cookie-policy td,#ot-sdk-cookie-policy tbody,#ot-sdk-cookie-policy .ot-main-content,#ot-sdk-cookie-policy .ot-toggle,#ot-sdk-cookie-policy #ot-content,#ot-sdk-cookie-policy #ot-pc-content,#ot-sdk-cookie-policy .checkbox,#ot-sync-ntfy div,#ot-sync-ntfy span,#ot-sync-ntfy h1,#ot-sync-ntfy h2,#ot-sync-ntfy h3,#ot-sync-ntfy h4,#ot-sync-ntfy h5,#ot-sync-ntfy h6,#ot-sync-ntfy p,#ot-sync-ntfy img,#ot-sync-ntfy svg,#ot-sync-ntfy button,#ot-sync-ntfy section,#ot-sync-ntfy a,#ot-sync-ntfy label,#ot-sync-ntfy input,#ot-sync-ntfy ul,#ot-sync-ntfy li,#ot-sync-ntfy nav,#ot-sync-ntfy table,#ot-sync-ntfy thead,#ot-sync-ntfy tr,#ot-sync-ntfy td,#ot-sync-ntfy tbody,#ot-sync-ntfy .ot-main-content,#ot-sync-ntfy .ot-toggle,#ot-sync-ntfy #ot-content,#ot-sync-ntfy #ot-pc-content,#ot-sync-ntfy .checkbox{font-family:inherit;font-weight:normal;-webkit-font-smoothing:auto;letter-spacing:normal;line-height:normal;padding:0;margin:0;height:auto;min-height:0;max-height:none;width:auto;min-width:0;max-width:none;border-radius:0;border:none;clear:none;float:none;position:static;bottom:auto;left:auto;right:auto;top:auto;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;white-space:normal;background:none;overflow:visible;vertical-align:baseline;visibility:visible;z-index:auto;box-shadow:none}#onetrust-banner-sdk label:before,#onetrust-banner-sdk label:after,#onetrust-banner-sdk .checkbox:after,#onetrust-banner-sdk .checkbox:before,#onetrust-pc-sdk label:before,#onetrust-pc-sdk label:afte ...
# #onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{position:relative;width:100%;max-width:100%;margin:0 auto;padding:0 20px;box-sizing:border-box}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{width:100%;float:left;box-sizing:border-box;padding:0;display:initial}@media (min-width: 400px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:90%;padding:0}}@media (min-width: 550px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:100%}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{margin-left:4%}#onetrust-banner-sdk .ot-sdk-column:first-child,#onetrust-banner-sdk .ot-sdk-columns:first-child,#onetrust-pc-sdk .ot-sdk-column:first-child,#onetrust-pc-sdk .ot-sdk-columns:first-child,#ot-sdk-cookie-policy .ot-sdk-column:first-child,#ot-sdk-cookie-policy .ot-sdk-columns:first-child{margin-left:0}#onetrust-banner-sdk .ot-sdk-two.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-two.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-two.ot-sdk-columns{width:13.3333333333%}#onetrust-banner-sdk .ot-sdk-three.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-three.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-three.ot-sdk-columns{width:22%}#onetrust-banner-sdk .ot-sdk-four.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-four.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-four.ot-sdk-columns{width:30.6666666667%}#onetrust-banner-sdk .ot-sdk-eight.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eight.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eight.ot-sdk-columns{width:65.3333333333%}#onetrust-banner-sdk .ot-sdk-nine.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-nine.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-nine.ot-sdk-columns{width:74%}#onetrust-banner-sdk .ot-sdk-ten.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-ten.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-ten.ot-sdk-columns{width:82.6666666667%}#onetrust-banner-sdk .ot-sdk-eleven.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eleven.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eleven.ot-sdk-columns{width:91.3333333333%}#onetrust-banner-sdk .ot-sdk-twelve.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-twelve.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-twelve.ot-sdk-columns{width:100%;margin-left:0}}#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6{margin-top:0;font-weight:600;font-family:inherit}#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem;line-height:1.2}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem;line-height:1.25}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size:1.5rem;line-height:1.3}#onetrust-banner-sdk h4,#onetrust-pc-sdk h4,#ot-sdk-cookie-policy h4{font-size:1.5rem;line-height:1.35}#onetrust-banner-sdk h5,#onetrust-pc-sdk h5,#ot-sdk-cookie-policy h5{font-size:1.5rem;line-height:1.5}#onetrust-banner-sdk h6,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h6{font-size:1.5rem;line-height:1.6}@media (min-width: 550px){#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size: ...
# #onetrust-banner-sdk{box-shadow:0 0 18px rgba(0,0,0,.2)}#onetrust-banner-sdk.otFlat{position:fixed;z-index:2147483645;bottom:0;right:0;left:0;background-color:#fff;max-height:90%;overflow-x:hidden;overflow-y:auto}#onetrust-banner-sdk.otFlat.top{top:0px;bottom:auto}#onetrust-banner-sdk.otRelFont{font-size:1rem}#onetrust-banner-sdk>.ot-sdk-container{overflow:hidden}#onetrust-banner-sdk::-webkit-scrollbar{width:11px}#onetrust-banner-sdk::-webkit-scrollbar-thumb{border-radius:10px;background:#c1c1c1}#onetrust-banner-sdk{scrollbar-arrow-color:#c1c1c1;scrollbar-darkshadow-color:#c1c1c1;scrollbar-face-color:#c1c1c1;scrollbar-shadow-color:#c1c1c1}#onetrust-banner-sdk #onetrust-policy{margin:1.25em 0 .625em 2em;overflow:hidden}#onetrust-banner-sdk #onetrust-policy .ot-gv-list-handler{float:left;font-size:.82em;padding:0;margin-bottom:0;border:0;line-height:normal;height:auto;width:auto}#onetrust-banner-sdk #onetrust-policy-title{font-size:1.2em;line-height:1.3;margin-bottom:10px}#onetrust-banner-sdk #onetrust-policy-text{clear:both;text-align:left;font-size:.88em;line-height:1.4}#onetrust-banner-sdk #onetrust-policy-text *{font-size:inherit;line-height:inherit}#onetrust-banner-sdk #onetrust-policy-text a{font-weight:bold;margin-left:5px}#onetrust-banner-sdk #onetrust-policy-title,#onetrust-banner-sdk #onetrust-policy-text{color:dimgray;float:left}#onetrust-banner-sdk #onetrust-button-group-parent{min-height:1px;text-align:center}#onetrust-banner-sdk #onetrust-button-group{display:inline-block}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{background-color:#68b631;color:#fff;border-color:#68b631;margin-right:1em;min-width:125px;height:auto;white-space:normal;word-break:break-word;word-wrap:break-word;padding:12px 10px;line-height:1.2;font-size:.813em;font-weight:600}#onetrust-banner-sdk #onetrust-pc-btn-handler.cookie-setting-link{background-color:#fff;border:none;color:#68b631;text-decoration:underline;padding-left:0;padding-right:0}#onetrust-banner-sdk .onetrust-close-btn-ui{width:44px;height:44px;background-size:12px;border:none;position:relative;margin:auto;padding:0}#onetrust-banner-sdk .banner_logo{display:none}#onetrust-banner-sdk .ot-b-addl-desc{clear:both;float:left;display:block}#onetrust-banner-sdk #banner-options{float:left;display:table;margin-right:0;margin-left:1em;width:calc(100% - 1em)}#onetrust-banner-sdk .banner-option-input{cursor:pointer;width:auto;height:auto;border:none;padding:0;padding-right:3px;margin:0 0 10px;font-size:.82em;line-height:1.4}#onetrust-banner-sdk .banner-option-input *{pointer-events:none;font-size:inherit;line-height:inherit}#onetrust-banner-sdk .banner-option-input[aria-expanded=true]~.banner-option-details{display:block;height:auto}#onetrust-banner-sdk .banner-option-input[aria-expanded=true] .ot-arrow-container{transform:rotate(90deg)}#onetrust-banner-sdk .banner-option{margin-bottom:12px;margin-left:0;border:none;float:left;padding:0}#onetrust-banner-sdk .banner-option:first-child{padding-left:2px}#onetrust-banner-sdk .banner-option:not(:first-child){padding:0;border:none}#onetrust-banner-sdk .banner-option-header{cursor:pointer;display:inline-block}#onetrust-banner-sdk .banner-option-header :first-child{color:dimgray;font-weight:bold;float:left}#onetrust-banner-sdk .banner-option-header .ot-arrow-container{display:inline-block;border-top:6px solid transparent;border-bottom:6px solid transparent;border-left:6px solid dimgray;margin-left:10px;vertical-align:middle}#onetrust-banner-sdk .banner-option-details{display:none;font-size:.83em;line-height:1.5;padding:10px 0px 5px 10px;margin-right:10px;height:0px}#onetrust-banner-sdk .banner-option-details *{font-size:inherit;line-height:inherit;color:dimgray}#onetrust-banner-sdk .ot-arrow-container,#onetrust-banner-sdk .banner-option-details{transition:all 300ms ease-in 0s;-webkit-transition:all 300ms ease-in 0s;-moz-transition:all 300ms ease-in 0s;-o ...
# #onetrust-consent-sdk #onetrust-banner-sdk {background-color: #FFF8F1;}
# #onetrust-consent-sdk #onetrust-policy-title,
# #onetrust-consent-sdk #onetrust-policy-text,
# #onetrust-consent-sdk .ot-b-addl-desc,
# #onetrust-consent-sdk .ot-dpd-desc,
# #onetrust-consent-sdk .ot-dpd-title,
# #onetrust-consent-sdk #onetrust-policy-text *:not(.onetrust-vendors-list-handler),
# #onetrust-consent-sdk .ot-dpd-desc *:not(.onetrust-vendors-list-handler),
# #onetrust-consent-sdk #onetrust-banner-sdk #banner-options *,
# #onetrust-banner-sdk .ot-cat-header {
# color: #000000;
# }
# #onetrust-consent-sdk #onetrust-banner-sdk .banner-option-details {
# background-color: #E9E9E9;}
# #onetrust-consent-sdk #onetrust-banner-sdk a[href],
# #onetrust-consent-sdk #onetrust-banner-sdk a[href] font,
# #onetrust-consent-sdk #onetrust-banner-sdk .ot-link-btn
# {
# color: #000000;
# }#onetrust-consent-sdk #onetrust-accept-btn-handler,
# #onetrust-banner-sdk #onetrust-reject-all-handler {
# background-color: #B1004D;border-color: #B1004D;
# color: #FFFFFF;
# }
# #onetrust-consent-sdk #onetrust-banner-sdk *:focus,
# #onetrust-consent-sdk #onetrust-banner-sdk:focus {
# outline-color: #000000;
# outline-width: 1px;
# }
# #onetrust-consent-sdk #onetrust-pc-btn-handler,
# #onetrust-consent-sdk #onetrust-pc-btn-handler.cookie-setting-link {
# color: #000000; border-color: #000000;
# background-color:
# #FFF8F1;
# } #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-close-btn-container {
# top: 25px;
# right: 25px;
# }
# #onetrust-consent-sdk #onetrust-banner-sdk .onetrust-close-btn-ui {
# width: 12px;
# height: 12px;
# }
# #onetrust-banner-sdk #onetrust-policy-text a.ot-sdk-show-settings {
# margin-left: 0;
# }
# #onetrust-consent-sdk #onetrust-button-group {
# text-align: center;
# }
# @media only screen and (min-width: 425px) and (max-width: 550px) {
# #onetrust-banner-sdk.ot-iab-2 #onetrust-button-group-parent #onetrust-button-group {
# width: auto;
# }
# }
# @media only screen and (min-width: 426px) and (max-width: 896px) {
# #onetrust-consent-sdk #onetrust-banner-sdk .onetrust-close-btn-ui {
# top: 0;
# right: 0;
# }
# }
# @media (min-width: 896px) {
# #onetrust-banner-sdk .ot-sdk-three.ot-sdk-columns {
# left: auto;
# right: 4%;
# margin-left: 0;
# margin-top: 5%;
# }
# }
# @media only screen and (min-width: 769px) {
# #onetrust-banner-sdk #onetrust-button-group {
# margin-right: 0;
# }
# }
# @media only screen and (min-width: 1024px){
# #onetrust-banner-sdk.ot-iab-2 #onetrust-button-group-parent {
# margin-top: 5%;
# }
# }
# #onetrust-consent-sdk #onetrust-banner-sdk {
# display: none;
# }
# /* hides banner after it has already been interacted with */
# #onetrust-consent-sdk:not(.show-banner) #onetrust-banner-sdk {
# display: none;
# }
#        </style>
#        <script data-glb-js="top" src="/static/1.10.0/cache/eNp9kt1ugzAMRl9oUd5h07SrSVXFC-THTV2SmCUOEzz9Aps2ylIkLsDfiXVMLDMrRiODiuxBGgoDRYicpVcTFZa3XB9hrmD6J3kP3xZonjLOUAmKF3R75OfLo853eKsVKQu2EYwQLSUZyEKKOCfxHTVIQ9Tj_-Y7iY8CacqcMLpGj8LokbGpeIniKLYUDvO3U_d4PL4m4vZYCSpToEvK9G3pUF-ETqD6gbBe3i-ynlY-Yxg8HMoNReeiG8HL-6lRPXfPjSovimfWryNsLTaiatJ_I262Tdn1btzALTflQIwIn_ts08BxWFfAo-kFP_hVG74uQDFcEthldbnWluPZiGryBUJ5KcY.min.js" type="text/javascript">
#        </script>
#        <script type="text/javascript">
#         var Mntl = window.Mntl || {};window.Mntl = window.Mntl || {};
#
# window.Mntl.csrf = function() {
#     return 'c11f58b25b216397dff825f050f5a19d';
# };(function() {
#     Mntl.utilities.onLoad(function() {
#         var geolocationResponse = {};
#         const externalJS = {
#             src: '\//cdn.cookielaw.org/scripttemplates/otSDKStub.js',
#             'data-domain-script': '5e3145a8-c535-445e-a7ee-89500c997868',
#             'data-ignore-ga': true,
#             'data-language': 'en',
#             async: true,
#             charset: 'UTF-8',
#             onerror: 'Mntl.CMP.onError()',
#             id: 'onetrust-script'
#         };
#         geolocationResponse.stateCode = 'PA';
#         geolocationResponse.countryCode = 'US';
#         geolocationResponse.regionCode = 'US';
#         if (Object.keys(geolocationResponse).length) {
#             window.OneTrust = window.OneTrust || {};
#             window.OneTrust.geolocationResponse = geolocationResponse;
#         }
#         const preferenceCenterTrigger = document.querySelector('.ot-pref-trigger');
#         preferenceCenterTrigger.addEventListener('click', (e) => {
#             e.preventDefault();
#             Mntl.utilities.loadExternalJS(
#                 externalJS
#             , () => {
#                 Mntl.CMP.onSdkLoaded(() => {
#                     OneTrust.ToggleInfoDisplay();
#                 })
#             });
#         },
#         { once: true });
#     });
#     Mntl.CMP.init(true, 'ccpa', false, 3000);
# })();
# window.Mntl = window.Mntl || {};
# Mntl.RTB = Mntl.RTB || {};
# Mntl.RTB.setTaxonomyStampValues({"tax1":"rsp_Home","tax2":"rsp_Decorating","tax0":"rsp"});
# Mntl.RTB.setTimeoutLength([750,1250]);
# Mntl.RTB.Plugins.amazon.amazonConfigs = {"mapTaxValues":{"tax1":"rsp_Home","tax2":"rsp_Decorating","si_section":"rsp_Decorating","tax0":"rsp","tax3":"null"},"mapFBValues":{"adunitid":"mapFBID"},"amazonSlotName":false,"amazonSection":"Decorating"};
# Mntl.RTB.initVideoBidders([{ type: 'amazon', id: '3446' }, { type: 'prebid', id: 'true' } ]);
# Mntl.RTB.initDisplayAndOutstreamBidders([{ type: "amazon", id: '3446'},{ type: "msg", id: 'true'},{ type: "lotameLightning", id: 'true'},{ type: "ixid", id: 'true'},{ type: "prebid", id: 'true'}]);
# Mntl.RTBTracking.init(['amazon','msg','lotameLightning','ixid','prebid']);
# Mntl.RTB.Plugins.lotameLightning.init({"tax1":"rsp_Home","tax2":"rsp_Decorating","tax0":"Real Simple","clientId":"10692"});
# Mntl.RTB.Plugins.prebid.setConfig({"leaderboard-fixed\/tier2":[{"bidder":"rubicon","params":{"accountId":"7499","siteId":"426792","zoneId":"2442130","type":"display"}},{"bidder":"appnexus","params":{"placementId":"21220318","type":"display"}},{"bidder":"onemobile","params":{"dcn":"8a9698a4017a7ae782afe89dced50049","pos":"rsm_leadrbrd_fixed_tier2_728x90"}},{"bidder":"ix","params":{"siteId":"446920","type":"display"}},{"bidder":"roundel","params":{"siteId":382319,"type":"display"}},{"bidder":"pubmatic","params":{"publisherId":"158139","adSlot":"3517574","type":"display"}},{"bidder":"trustx","params":{"uid":"22509","useNewFormat":true,"type":"display"}}],"square-fixed\/tier1":[{"bidder":"ix","params":{"siteId":"446943","type":"display"}},{"bidder":"roundel","params":{"siteId":382319,"type":"display"}},{"bidder":"onemobile","params":{"dcn":"8a9698a4017a7ae782afe89dced50049","pos":"rsm_square_fixed_tier1_300x250"}},{"bidder":"pubmatic","params":{"publisherId":"158139","adSlot":"3517575","type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"426792","zoneId":"2442138","type":"display"}},{"bidder":"appnexus","params":{"placementId":"21220326","type":"display"}},{"bidder":"trustx","params":{"uid":"22517","useNewFormat":true,"type":"display"}}],"square-fixed\/tier2":[{"bidder":"onemobile","params":{"dcn":"8a9698a4017a7ae782afe89dced50049","pos":"rsm_square_fixed_tier2_300x250"}},{"bidder":"ix","params":{"siteId":"446944","type":"display"}},{"bidder":"roundel","params":{"siteId":382319,"type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"426792","zoneId":"2442140","type":"display"}},{"bidder":"appnexus","params":{"placementId":"21220327","type":"display"}},{"bidder":"trustx","params":{"uid":"22518","useNewFormat":true,"type":"display"}},{"bidder":"pubmatic","params":{"publisherId":"158139","adSlot":"3517579","type":"display"}}],"leaderboard-fixed\/tier1":[{"bidder":"pubmatic","params":{"publisherId":"158139","adSlot":"3517572","type":"display"}},{"bidder":"appnexus","params":{"placementId":"21220317","type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"426792","zoneId":"2442128","type":"display"}},{"bidder":"onemobile","params":{"dcn":"8a9698a4017a7ae782afe89dced50049","pos":"rsm_leadrbrd_fixed_tier1_728x90"}},{"bidder":"roundel","params":{"siteId":382319,"type":"display"}},{"bidder":"ix","params":{"siteId":"446919","type":"display"}},{"bidder":"trustx","params":{"uid":"22508","useNewFormat":true,"type":"display"}}],"square-fixed\/tier3":[{"bidder":"onemobile","params":{"dcn":"8a9698a4017a7ae782afe89dced50049","pos":"rsm_square_fixed_tier3_300x250"}},{"bidder":"roundel","params":{"siteId":382319,"type":"display"}},{"bidder":"pubmatic","params":{"publisherId":"158139","adSlot":"3518007","type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"426792","zoneId":"2442142","type":"display"}},{"bidder":"ix","params":{"siteId":"446945","type":"display"}},{"bidder":"trustx","params":{"uid":"22519","useNewFormat":true,"type":"display"}},{"bidder":"appnexus","params":{"placementId":"21220328","type":"display"}}],"square-fixed\/tier4":[{"bidder":"trustx","params":{"uid":"22520","useNewFormat":true,"type":"display"}},{"bidder":"onemobile","params":{"dcn":"8a9698a4017a7ae782afe89dced50049","pos":"rsm_square_fixed_tier4_300x250"}},{"bidder":"ix","params":{"siteId":"446946","type":"display"}},{"bidder":"roundel","params":{"siteId":382319,"type":"display"}},{"bidder":"appnexus","params":{"placementId":"21220329","type":"display"}},{"bidder":"pubmatic","params":{"publisherId":"158139","adSlot":"3517581","type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"426792","zoneId":"2442144","type":"display"}}],"preroll":[{"bidder":"rubicon","params":{"accountId":"7499","siteId":"426792","zoneId":"2442150","type":"instream"}},{"bidder":"trustx","params":{"uid":"22638","useNewFormat":true,"type":"instream"}},{"bidder":"appnexus","params":{"placeme ...
# Mntl.RTB.Plugins.prebid.setPriceGranularity({"buckets":[{"max":"20","increment":"0.05"},{"max":"100","increment":"0.5"}]});
# Mntl.RTB.setLatencyBuffer(0);
# (function(){
# const pageTargeting = {
# rec: 0
# ,customSeries: ''
# ,tax0: 'Real Simple'
# ,custom: ''
# ,rid: 'n22d9817a258842b2afa34d17269ef80921'
# ,sid: 'n22d9817a258842b2afa34d17269ef80921'
# }
# ;
# const baseSlotTargeting = {
# leaid: '1009520'
# ,docId: '6375142'
# ,viewtype: 'taxonomy'
# ,type: 'taxonomy'
# ,ptax: 'rsp_Decorating'
# ,vid: '0'
# ,tax1: 'rsp_Home'
# ,tax2: 'rsp_Decorating'
# ,tier: 'L'
# ,leuid: '153546959002053'
# ,id: '6375142'
# ,tax3: ''
# ,tax4: ''
# ,inf: '0'
# ,entryType: 'direct'
# ,gtemplate: 'taxonomy'
# ,revenueGroup: ''
# ,chpg: '1'
# ,t: '140'
# ,au: '1009520'
# ,jny: '0'
# ,sbj: 'pidrsp_Decorating'
# ,aid: ''
# ,jnyroot: ''
# }
# ;
# pageTargeting.w = Mntl.utilities.getW();
# const refreshAdhesive = {
# afterAdhesiveRenderedTimeout: '25000'
# }
# ;
# const initialSlots = [];
# initialSlots.push({
# config: {
# id: 'oop',
# sizes: [[1, 1]],
# type: 'outofpage',
# rtb: false
# },
# targeting: Mntl.fnUtilities.deepExtend({}, {
# pos: 'atf',
# priority: 0
# ,floor_id: '7073a65b938b424ca06a483fc42c926b'
# ,floor: '5'
# })
# })
# initialSlots.push({
# config: {
# id: 'leaderboard-flex-1',
# sizes: [[728, 90], [970,90], [970, 250]],
# type: 'leaderboard',
# rtb: true
# },
# targeting: Mntl.fnUtilities.deepExtend({}, {
# pos: 'atf',
# priority: 1
# ,floor_id: 'cf57c4f8f01f4dcfae82d15444233e30'
# ,floor: '5'
# })
# })
# const testIds = Mntl.GPT.getTestIds();
# pageTargeting.ab = testIds;
# pageTargeting.bts = testIds;
# Mntl.utilities.onLoad(function() {
# Mntl.utilities.loadExternalJS({
# src: '//securepubads.g.doubleclick.net/tag/js/gpt.js',
# async: false
# });
# });
# const options = {
# domain: 'www.realsimple.com',
# templateName: 'taxonomysc',
# isMobile: false,
# dfpId: '3865',
# publisherProvidedId: '908ce980-a1dd-49e5-93aa-452c70d6ec99',
# singleRequest: true,
# useLmdFormat: true,
# useOxygen: true,
# useInfiniteRightRail: true,
# bundlePrebid: false,
# lmdSiteCode: 'rs',
# pageTargeting,
# baseSlotTargeting,
# geo: {
# isInEurope: false,
# isInUsa: true
# },
# initialSlots,
# utils: {
# generateSlotId: Realsimple.GPT.generateSlotId
# },
# displayOnScroll: 'false',
# displayOnConsent: 'true',
# refreshAdhesive
# };
# Mntl.GPT.init(options);
# }());// moved from gtm.ftl so we can initialize GTM only onLoad. From https://support.google.com/tagmanager/answer/6103696?hl=en
# Mntl.utilities.onLoad(function() {
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;defer=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-P3X3VT7');
# });
# var dataLayer = dataLayer || [];
# dataLayer.push({
# event: 'ab-proctor',
# 'abTests-proctor': {
# "60"
# : "rtbTracking | control | | 0"
# ,
# "99-1"
# : "useOxygen | useOxygen | use the Oxygenated ad unit format and slot names | 1"
# ,
# "99-2"
# : "useInfiniteRightRail | useInfiniteRightRail | Use infinite right rail | 1"
# ,
# "99-3"
# : "broadVideo | active | broad video enabled | 1"
# ,
# "99-4"
# : "useRTBforVideoAds | active | | 1"
# }
# });
# dataLayer.push({
# envData: {
# environment: {
# environment: "k8s-prod",
# application: "realsimple",
# dataCenter: "us-east-1"
# },
# server: {
# version: "1.10.0",
# title: "realsimple-launcher"
# },
# client : {
# browserUA: navigator.userAgent,
# serverUA: "python-requests/2.28.1",
# deviceType: "pc",
# usStateCode: "PA"
# },
# mantle: "3.13.441",
# commerce: ""
# }
# });
# (function(win, fnUtils, CMP) {
# var pageViewDataAsJSON = {"country":"US","description":"Whether you&#39;re looking for living room decorating ideas or the trendiest paint colors, you&#39;ve come to the right place. Here&#39;s how to decorate a beautiful home.","muid":"908ce980-a1dd-49e5-93aa-452c70d6ec99","contentGroup":"Other","revenueGroup":"","authorId":"1009520","documentId":6375142,"title":"Decorating Ideas for Every Room in Your House | Real Simple" || document.title || '',"templateName":"TAXONOMYSC","lastEditingAuthorId":"1009520","lastEditingUserId":"153546959002053","templateId":"140","viewType":"TAXONOMY","fullUrl":"https://www.realsimple.com/home-organizing/decorating" + location.hash,"experienceType":"single page","entryType":"direct","excludeFromComscore":false,"socialImage":"https://www.realsimple.com/thmb/wGzyxMRnbAsWz8eMWp_LgYG0ihA=/735x0/decorating-banner-2000-026f9d1b9f9f44a2a9a9b2570bf27261.jpg","internalSessionId":"n22d9817a258842b2afa34d17269ef80921","internalRequestId":"n22d9817a258842b2afa34d17269ef80921","hid":"","experienceTypeName":"","recircDocIdsFooter":"","euTrafficFlag":false,"isGoogleBot":false,"mantleVersion":"3.13.441","commerceVersion":"","primaryTaxonomyIds":"5509608|6375312|6375142","primaryTaxonomyNames":"RealSimple|Home|Decorating"};
# var deferLoadTime = 5000;
# var readyForThirdPartyTrackingEvent = new CustomEvent('readyForThirdPartyTracking', { bubbles: true });
# var readyForThirdPartyTracking = fnUtils.once(function() {
# dataLayer.push({event: 'readyForThirdPartyTracking'});
# window.dispatchEvent(readyForThirdPartyTrackingEvent);
# });
# var hasTargetingConsentHandler = function() {
# const hasConsent = CMP.hasTargetingConsent();
# if (hasConsent) {
# readyForThirdPartyTracking();
# }
# return hasConsent;
# };
# var onRequiredDomEvent = fnUtils.once(function() {
# if (!CMP) {
# readyForThirdPartyTracking();
# return;
# }
# if (!CMP.isLoading()) {
# hasTargetingConsentHandler();
# }
# CMP.onConsentChange(hasTargetingConsentHandler);
# });
# [
# ['adRendered', onRequiredDomEvent],
# ['beforeunload', onRequiredDomEvent],
# ['load', function() { setTimeout(onRequiredDomEvent, deferLoadTime); }]
# ].forEach(function(event) {
# win.addEventListener(event[0], event[1], { once: true });
# });
# pageViewDataAsJSON.breakpointName = Realsimple.utilities.getW();
# pageViewDataAsJSON.bounceExchangeId = '2548';
# Mntl.utilities.onLoad(function() {
# Mntl.PageView.init(pageViewDataAsJSON);
# });
# })(window || {}, Mntl.fnUtilities || {}, Mntl.CMP);
#        </script>
#        <link href="/favicon.ico" rel="shortcut icon"/>
#        <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#        <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#        <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#        <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#        <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#        <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#        <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#        <meta content="#F4F4F4" name="msapplication-TileColor"/>
#        <meta content="/static/1.10.0/icons/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#        <meta content="/static/1.10.0/icons/favicons/mstile-70x70.png" name="msapplication-square70x70logo"/>
#        <meta content="/static/1.10.0/icons/favicons/mstile-150x150.png" name="msapplication-square150x150logo"/>
#        <meta content="/static/1.10.0/icons/favicons/mstile-310x310.png" name="msapplication-square310x310logo"/>
#        <meta content="/static/1.10.0/icons/favicons/mstile-310x150.png" name="msapplication-wide310x150logo"/>
#        <script class="comp realsimple-schema mntl-schema-unified" id="realsimple-schema_1-0" type="application/ld+json">
#         {
# "@context": "http://schema.org",
#
# "@type": ["ItemList","CollectionPage"]
# ,"itemListElement":[
# {
# "@type": "ListItem"
# ,"position": 1
# ,"url": "https://www.realsimple.com/home-organizing/gardening/indoor/plant-shelf-ideas"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 2
# ,"url": "https://www.realsimple.com/home-organizing/decorating/outdoor-living/small-front-porch-decorating-ideas"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 3
# ,"url": "https://www.realsimple.com/home-organizing/decorating/decorating-bedroom/best-cooling-bed-sheets"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 4
# ,"url": "https://www.realsimple.com/holidays-entertaining/holidays/christmas/decoration-ideas/christmas-tree-collars"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 5
# ,"url": "https://www.realsimple.com/holidays-entertaining/holidays/etsy-holiday-trends-2021"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 6
# ,"url": "https://www.realsimple.com/home-organizing/home-improvement/painting/paint-trends-2021"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 7
# ,"url": "https://www.realsimple.com/home-organizing/home-improvement/painting/farrow-and-ball-kelly-wearstler"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 8
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-moody-home-office"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 9
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-paint-colors-real-simple-home-2022"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 10
# ,"url": "https://www.realsimple.com/home-organizing/decorating/shop-the-real-simple-home-2022"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 11
# ,"url": "https://www.realsimple.com/home-organizing/decorating/dabito-design-tips"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 12
# ,"url": "https://www.realsimple.com/home-organizing/decorating/clever-items-real-simple-home"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 13
# ,"url": "https://www.realsimple.com/home-organizing/decorating/real-simple-home-coastal-grandmother-style"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 14
# ,"url": "https://www.realsimple.com/home-organizing/decorating/real-simple-home-decor-trends-fall-2022"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 15
# ,"url": "https://www.realsimple.com/home-organizing/decorating/persian-area-rugs-1909-checkered-area-rug-amazon"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 16
# ,"url": "https://www.realsimple.com/home-organizing/decorating/sunroom-ideas"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 17
# ,"url": "https://www.realsimple.com/home-organizing/decorating/brightech-maxwell-floor-lamp-and-shelving-unit-amazon"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 18
# ,"url": "https://www.realsimple.com/home-organizing/decorating/philips-wake-up-light-amazon-sale"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 19
# ,"url": "https://www.realsimple.com/home-organizing/decorating/philips-hue-smart-light-bulbs-amazon-sale"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 20
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-cloffice"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 21
# ,"url": "https://www.realsimple.com/home-organizing/decorating/how-to-incorporate-barbiecore-into-your-decor"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 22
# ,"url": "https://www.realsimple.com/home-organizing/decorating/types-of-tiles"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 23
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-throw-pillows"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 24
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-hall-trees"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 25
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-laundry-room-renovation"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 26
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-rugs"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 27
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-storage-furniture"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 28
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-entryway-tables"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 29
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-zooey-deschanel-craft-room"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 30
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-wallpaper"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 31
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-jasmine-roth-home-office"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 32
# ,"url": "https://www.realsimple.com/home-organizing/home-improvement/painting/sage-green-paint"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 33
# ,"url": "https://www.realsimple.com/home-organizing/decorating/wayfair-memorial-day-sale-2022"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 34
# ,"url": "https://www.realsimple.com/home-organizing/decorating/amazon-coastal-grandmother-home-decor-storefront"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 35
# ,"url": "https://www.realsimple.com/home-organizing/decorating/real-simple-home-2022-introduction"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 36
# ,"url": "https://www.realsimple.com/home-organizing/decorating/real-simple-home-2022-designers"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 37
# ,"url": "https://www.realsimple.com/home-organizing/decorating/different-types-wood"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 38
# ,"url": "https://www.realsimple.com/home-organizing/home-improvement/painting/what-is-chalk-paint"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 39
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-removable-wallpaper"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 40
# ,"url": "https://www.realsimple.com/home-organizing/decorating/tips-techniques/entryway-ideas-first-impression"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 41
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-rug-pads"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 42
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-storage-ottomans"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 43
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-blue-home-office"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 44
# ,"url": "https://www.realsimple.com/home-organizing/best-essential-oil-diffuser"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 45
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-bunk-beds-for-adults"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 46
# ,"url": "https://www.realsimple.com/home-organizing/decorating/best-places-to-buy-art-online"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 47
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-cottage-kitchen-ikea-hack"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 48
# ,"url": "https://www.realsimple.com/home-organizing/decorating/natural-materials-decor-storefront-amazon"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 49
# ,"url": "https://www.realsimple.com/home-organizing/decorating/early-way-day-deals-wayfair-2022"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 50
# ,"url": "https://www.realsimple.com/home-organizing/decorating/wayfair-warehouse-clearout-sale-2022-entryway-furniture"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 51
# ,"url": "https://www.realsimple.com/home-organizing/decorating/home-design-apps-services"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 52
# ,"url": "https://www.realsimple.com/home-organizing/target-outdoor-doormats"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 53
# ,"url": "https://www.realsimple.com/home-organizing/decorating/jcrew-home-bedding-launch-spring-2022"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 54
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-gallery-wall-staircase"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 55
# ,"url": "https://www.realsimple.com/home-organizing/decorating/amazon-spring-into-summer-home-decor"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 56
# ,"url": "https://www.realsimple.com/home-organizing/organizing/organizing-home-office/simply-modern-home-office-makeover"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 57
# ,"url": "https://www.realsimple.com/home-organizing/decorating/front-porch-decor-for-spring-simply"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 58
# ,"url": "https://www.realsimple.com/home-organizing/decorating/lemomo-blackout-curtains-amazon"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 59
# ,"url": "https://www.realsimple.com/home-organizing/decorating/desert-home-amazon-storefront"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 60
# ,"url": "https://www.realsimple.com/home-organizing/decorating/decorating-bedroom/eddie-bauer-home-percale-sheet-set-amazon"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 61
# ,"url": "https://www.realsimple.com/work-life/entertainment/crafts-hobbies/simply-video-diy-faux-clay-vases"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 62
# ,"url": "https://www.realsimple.com/home-organizing/decorating/space-of-the-week-blue-kitchen"
# }
# ,
# {
# "@type": "ListItem"
# ,"position": 63
# ,"url": "https://www.realsimple.com/home-organizing/decorating/surprising-things-shop-at-homegoods"
# }
# ]
# ,"numberOfItems": 63
# ,"mainEntityOfPage": {
# "@type": ["CollectionPage"]
# ,"@id": "https://www.realsimple.com/home-organizing/decorating"
# ,"breadcrumb": {
# "@type": "BreadcrumbList",
# "itemListElement": [
# {
# "@type": "ListItem",
# "position": 1,
# "item": {
# "@id": "https://www.realsimple.com/home-organizing",
# "name": "Home"
# }
# }
# ,
# {
# "@type": "ListItem",
# "position": 2,
# "item": {
# "@id": "https://www.realsimple.com/home-organizing/decorating",
# "name": "Decorating"
# }
# }
# ]
# }
# ,"headline": "Decorating"
# ,"datePublished": "2020-04-11T19:50:16.000-04:00"
# ,"dateModified": "2021-12-09T11:49:46.000-05:00"
# ,"author": [
# {"@type": "Person"
# ,"name": "Real Simple Editors"
# ,"description": "An article attributed to &#34;Real Simple Editors&#34; indicates a collaborative effort from our in-house team. Sometimes, several writers and editors have contributed to an article over the years. These collaborations allow us to provide you with the most accurate, up-to-date, and comprehensive information available. The REAL SIMPLE team strives to make life easier for you. They are experts in their fields who research, test and clearly explain the best recipes, strategies, trends and products. They have worked for some of the most prestigious brands in lifestyle journalism, including Apartment Therapy, Better Homes &amp; Gardens, Food &amp; Wine, the Food Network, Good Housekeeping, InStyle, Martha Stewart Living, O: The Oprah Magazine, Parents, POPSUGAR, Rachel Ray Every Day, and Vogue."
# ,"url": "https://www.realsimple.com/author/real-simple-editors"
# ,"sameAs": [
# "https://www.facebook.com/realsimple",
# "https://twitter.com/realsimple",
# "https://www.instagram.com/real_simple/"
# ]
# }
# ]
# ,"description": "Whether you&#39;re looking for living room decorating ideas or the trendiest paint colors, you&#39;ve come to the right place. Here&#39;s how to decorate a beautiful home."
# , "Specialty" : "Decorating"
# ,"publisher": {
# "@type": "Organization",
# "name": "Real Simple",
# "url": "https://www.realsimple.com",
# "logo": {
# "@type": "ImageObject",
# ...
#         <li>
#          <a aria-label="Visit Real Simple's tiktok page" class="social-follow__button social-follow__button-tiktok" data-network="tiktok" href="https://www.tiktok.com/@realsimple">
#           <svg class="icon icon-tiktok">
#            <use xlink:href="#icon-tiktok" xmlns:xlink="http://www.w3.org/1999/xlink">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a aria-label="Visit Real Simple's flipboard page" class="social-follow__button social-follow__button-flipboard" data-network="flipboard" href="https://flipboard.com/@RealSimple">
#           <svg class="icon icon-flipboard">
#            <use xlink:href="#icon-flipboard" xmlns:xlink="http://www.w3.org/1999/xlink">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <!-- end: comp extended social-follow -->
#      </div>
#     </div>
#     <div class="footer__secondary">
#      <nav class="comp footer-nav mntl-block" id="footer-nav_1-0">
#       <ul class="comp footer-nav__list mntl-block" id="mntl-block_1-0">
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/food-recipes" id="mntl-text-block_3-0">
#          Food
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-1">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/home-organizing" id="mntl-text-block_3-0-1">
#          Home
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-2">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/work-life" id="mntl-text-block_3-0-2">
#          Life
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-3">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/health" id="mntl-text-block_3-0-3">
#          Health
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-4">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/work-life/money" id="mntl-text-block_3-0-4">
#          Money
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-5">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/beauty-fashion" id="mntl-text-block_3-0-5">
#          Style and Beauty
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-6">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/holidays-entertaining" id="mntl-text-block_3-0-6">
#          Holidays &amp; Entertaining
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-7">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/news" id="mntl-text-block_3-0-7">
#          News
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#        <li class="comp footer-nav__list-item mntl-block" id="footer-nav__list-item_1-0-8">
#         <a class="comp type--squirrel-link mntl-text-block" href="https://www.realsimple.com/shopping" id="mntl-text-block_3-0-8">
#          Shopping
#         </a>
#         <!-- end: comp type--squirrel-link mntl-text-block -->
#        </li>
#        <!-- end: comp footer-nav__list-item mntl-block -->
#       </ul>
#       <!-- end: comp footer-nav__list mntl-block -->
#      </nav>
#      <!-- end: comp footer-nav mntl-block -->
#      <ul class="comp footer-links" id="footer-links_1-0">
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="ourStory" href="/about-us-5546943" rel="nocaes">
#         About Us
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="subscribe" href="https://www.magazines.com/real-simple-magazine.html" rel="noopener nocaes" target="_blank">
#         Subscribe
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="editorialGuidelines" href="/about-us-5546943#toc-editorial-guidelines" rel="nocaes">
#         Editorial Guidelines
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="productTestingGuidelines" href="/real-simple-selects-seal-approval-5649700" rel="nocaes">
#         Product Testing Guidelines
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="privacyPolicy" href="https://www.dotdashmeredith.com/brands-privacy" rel="noopener nocaes" target="_blank">
#         Privacy Policy
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="diversityPledge" href="/diversity-inclusion-pledge-5547660" rel="nocaes">
#         Diversity &amp; Inclusion Pledge
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="termsOfUse" href="https://www.dotdashmeredith.com/terms-of-use" rel="noopener nocaes" target="_blank">
#         Terms of Use
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="termsOfUse" href="https://www.meredithcontentlicensing.com/" rel="noopener nocaes" target="_blank">
#         Content Licensing
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="advertise" href="https://promo.realsimple.com/" rel="nocaes">
#         Advertise
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="accolades" href="https://meredithaccolades.com/index.html" rel="noopener nocaes" target="_blank">
#         Accolades
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item ot-pref-trigger">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="cmpFooterLink" href="#" rel="nocaes">
#         Do Not Sell My Personal Information
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="careersAtDotDash" href="https://www.dotdashmeredith.com/careers/" rel="noopener nocaes" target="_blank">
#         Careers
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#       <li class="footer-links__item">
#        <a class="type--rabbit-link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="contact" href="/about-us-5546943#toc-contacts" rel="nocaes">
#         Contact Us
#        </a>
#        <!-- end: type--rabbit-link -->
#       </li>
#      </ul>
#      <!-- end: comp footer-links -->
#     </div>
#    </div>
#    <div class="loc footer-bottom">
#     <nav class="comp mntl-dotdash-universal-nav" data-tracking-container="true" id="mntl-dotdash-universal-nav_1-0" role="navigation">
#      <div class="mntl-dotdash-universal-nav__content">
#       <svg class="icon mntl-dotdash-universal-nav__logo">
#        <use xlink:href="#mntl-dotdash-universal-nav__logo" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#       <span class="mntl-dotdash-universal-nav__text">
#        Real Simple is part of the
#        <a class="mntl-dotdash-universal-nav__text--link" href="https://www.dotdashmeredith.com" target="_blank">
#         Dotdash Meredith
#        </a>
#        publishing family.
#       </span>
#       <span class="mntl-dotdash-universal-nav__separator">
#       </span>
#       <span class="mntl-dotdash-universal-nav__privacy-policy">
#        We've updated our Privacy Policy, which will go in to effect on September 1, 2022.
#        <a class="mntl-dotdash-universal-nav__privacy-policy--link" href="https://www.dotdashmeredith.com/brands-privacy" target="_blank">
#         Review our Privacy Policy
#        </a>
#       </span>
#      </div>
#     </nav>
#     <!-- end: comp mntl-dotdash-universal-nav -->
#    </div>
#   </footer>
#   <!-- end: comp footer -->
#   <div aria-hidden="true" class="comp newsletter-dialog-header mntl-dialog dialog" data-a11y-dialog="newsletter-dialog-header" id="newsletter-dialog-header_1-0">
#    <div class="dialog__overlay" data-a11y-dialog-hide="" tabindex="-1">
#    </div>
#    <div aria-labelledby="newsletter-dialog-header_1-0-title" class="dialog__content" role="dialog">
#     <div class="dialog__heading">
#      <span class="dialog__title type--monkey-bold" id="newsletter-dialog-header_1-0-title">
#       Newsletter Sign Up
#      </span>
#      <button aria-label="Close this dialog window" class="dialog__close" data-a11y-dialog-hide="">
#       <svg class="icon icon-close">
#        <use xlink:href="#icon-close" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#      </button>
#     </div>
#     <div class="loc content dialog__main">
#      <div class="comp newsletter mntl-newsletter" data-defer="loadDialogContent" data-defer-params="" id="newsletter_1-0">
#      </div>
#      <!-- end: comp newsletter mntl-newsletter -->
#     </div>
#    </div>
#   </div>
#   <!-- end: comp newsletter-dialog-header mntl-dialog dialog -->
#   <div aria-hidden="true" class="comp newsletter-dialog-footer newsletter-dialog-header mntl-dialog dialog" data-a11y-dialog="newsletter-dialog-footer" id="newsletter-dialog-footer_1-0">
#    <div class="dialog__overlay" data-a11y-dialog-hide="" tabindex="-1">
#    </div>
#    <div aria-labelledby="newsletter-dialog-footer_1-0-title" class="dialog__content" role="dialog">
#     <div class="dialog__heading">
#      <span class="dialog__title type--monkey-bold" id="newsletter-dialog-footer_1-0-title">
#       Newsletter Sign Up
#      </span>
#      <button aria-label="Close this dialog window" class="dialog__close" data-a11y-dialog-hide="">
#       <svg class="icon icon-close">
#        <use xlink:href="#icon-close" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#      </button>
#     </div>
#     <div class="loc content dialog__main">
#      <div class="comp newsletter mntl-newsletter" data-defer="loadDialogContent" data-defer-params="" id="newsletter_2-0">
#      </div>
#      <!-- end: comp newsletter mntl-newsletter -->
#     </div>
#    </div>
#   </div>
#   <!-- end: comp newsletter-dialog-footer newsletter-dialog-header mntl-dialog dialog -->
#   <svg class="is-hidden">
#    <defs>
#     <symbol id="mntl-sc-block-starrating-icon">
#      <svg viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg">
#       <path d="M0,0v20h20V0H0z M14.2,12.2l1.1,6.3l-5.4-3.2l-5.1,3.2l1-6.3L1.4,8l5.9-0.8l2.6-5.8l2.7,5.8L18.5,8L14.2,12.2z">
#       </path>
#      </svg>
#     </symbol>
#    </defs>
#   </svg>
#   <div class="comp mntl-outofpage mntl-outofpage mntl-gpt-adunit gpt outofpage" id="mntl-outofpage_1-0">
#    <div class="wrapper" id="oop">
#    </div>
#   </div>
#   <!-- end: comp mntl-outofpage mntl-outofpage mntl-gpt-adunit gpt outofpage -->
#   <script async="" data-glb-js="bottom" defer="true" src="/static/1.10.0/cache/eNqNVFFuwyAMvdAQ6hkq7Wtf2wkccIg3BzYgSdPTD0irpmmaVIoED56N3zNEhgiRlGzBRkZ5QUxVkN_p--vQj2_ynpQ2ukhMkTCIqiOOYqDYiKfsNk1ED5aYQQTlHfOSpVz76yzaGCTZiN4CS401-hxfJh71Surj1-f7k4NnKfE0paQzCib7U8Q9LG4kgLpOgiFOTOFx8BSn4p5sbSQbSBtMY4NkmnhswBr8oBDRpoxri1tmtWCKEYbqrfp1kcxwHgXcfJwxAqpIzgYZ4eSsa0dhncYlfEFVcIqARWjAl8LmeKdCm_b6242Z4EbMtbagcswNCdUQawE-hXHuS4hrkg27Kl2zBkEX4_OwxqudbxM7dyILQfCqWcC1sKshLYaQmiQqsLnB93BDnU62OXMZyuVaO8VCTwZy6y4Kkm39bLoTU3fM6UUi2hJ3D_cvVH7KMMC4z6wZT1SlbsDDM178dOBwGMWk-lV3_gFIYdOM.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Mntl.utilities.scriptsOnLoad(document.querySelectorAll('script[data-glb-js="bottom"]'), function() {var Mntl = window.Mntl || {};window.Mntl.externalizeLinks.addPlugin(window.Mntl.affiliateLinkRewriter);
# window.Mntl.externalizeLinks.addPlugin(window.Mntl.amazonAffiliateTagger);
# window.Mntl.externalizeLinks.init();window.Mntl.affiliateLinkRewriter.setMappings( {
# DOC_ID: '6375142'
# ,SITE: 'realsimple'
# ,REQUEST_ID: 'n22d9817a258842b2afa34d17269ef80921'
# }
# );
# });
#   </script>
#   <div class="comp mntl-sponsor-tracking-codes" data-defer="load" data-defer-params="" id="mntl-sponsor-tracking-codes_1-0">
#   </div>
#   <!-- end: comp mntl-sponsor-tracking-codes -->
#   <div class="" data-tracking-container="true" id="onetrust-consent-sdk">
#    <div class="otFlat bottom ot-wo-title" id="onetrust-banner-sdk" tabindex="0">
#     <div aria-describedby="onetrust-policy-text" aria-label="Privacy" role="alertdialog">
#      <div class="ot-sdk-container">
#       <div class="ot-sdk-row">
#        <div class="ot-sdk-eight ot-sdk-columns" id="onetrust-group-container">
#         <div class="banner_logo">
#         </div>
#         <div id="onetrust-policy">
#          <p id="onetrust-policy-text">
#           By clicking “Accept All Cookies”, you agree to the storing of cookies on your device to enhance site navigation, analyze site usage, and assist in our marketing efforts.
#          </p>
#         </div>
#        </div>
#        <div class="ot-sdk-three ot-sdk-columns" id="onetrust-button-group-parent">
#         <div id="onetrust-button-group">
#          <button class="cookie-setting-link" id="onetrust-pc-btn-handler">
#           Cookies Settings
#          </button>
#          <button id="onetrust-accept-btn-handler">
#           Accept All Cookies
#          </button>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- Close Button -->
#      <div id="onetrust-close-btn-container">
#       <button aria-label="Close" class="onetrust-close-btn-handler onetrust-close-btn-ui banner-close-button ot-close-icon">
#       </button>
#      </div>
#      <!-- Close Button END-->
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <!-- end: comp no-js taxlevel-2 taxlevel-2 taxonomyScTemplate html mntl-html -->

# %%
list1 = soup.find('div',{"class" : "comp three-post__inner card-list mntl-document-card-list mntl-card-list mntl-block"})
list2 = list1.find_all('a')

# %%
for title in list2:
    details = []
    details.append(title.find("div",{"class":"card__content"}).get("data-tag"))
    details.append(title.get("href")) #link to the article
    details.append(title.find('span',{"class":"card__title"}).contents[0].contents[0])
    details.append(title.find('div',{"class":"img-placeholder"}).find('img').get("data-src"))
    data.append(details)

# %%
data
# Out:
# [['House Plants',
#   'https://www.realsimple.com/home-organizing/gardening/indoor/plant-shelf-ideas',
#   'The Best Plant Shelf Ideas to Keep Your Plant Babies Thriving',
#   'https://www.realsimple.com/thmb/czI32_i_6UKLr2qZMDW6R_WArTU=/364x242/filters:no_upscale():max_bytes(150000):strip_icc()/best-plant-shelf-ideas-9491b92ac3384af883433baa67667ec3.jpg'],
#  ['Outdoor Living',
#   'https://www.realsimple.com/home-organizing/decorating/outdoor-living/small-front-porch-decorating-ideas',
#   'Create a Warm Welcome With Small Front Porch Decorating Ideas',
#   'https://www.realsimple.com/thmb/87689cG2ofLLYRpyEOTLfDQv9OI=/364x242/filters:no_upscale():max_bytes(150000):strip_icc()/porch-decorating-ideas-998cbac365b34cf189e603e756865934.jpg'],
#  ['Bedroom Decorating',
#   'https://www.realsimple.com/home-organizing/decorating/decorating-bedroom/best-cooling-bed-sheets',
#   'The 10 Best Cooling Sheets for a Sweat-Free Night, According to Our Tests',
#   'https://www.realsimple.com/thmb/tZx1ZonOL84XRmy538dalyZB8iU=/364x242/filters:no_upscale():max_bytes(150000):strip_icc()/best-cooling-sheets-lead-tout-2000-dd035fc87c6b484ca34346876d15b4b0.jpg']]

# %%
links=soup.find("div",{"class":"comp tax-sc__recirc-list card-list mntl-document-card-list mntl-card-list mntl-block"})
a = links.find_all('a')
len(links)

# %%
for atags in a:
    details = []
    details.append(atags.find("div",{"class":"card__content"}).get("data-tag"))
    details.append(title.get("href")) #link to the article
    details.append(atags.find('span',{"class":"card__title"}).contents[0].contents[0])
    details.append(atags.find('div',{"class":"img-placeholder"}).find('img').get("data-src"))
    data.append(details)
    count=count+1

# %%
df = pd.DataFrame (data, columns = ['Category','Link','Title','Image_Link'])

# %%
df
# Out:
#                       Category  \
# 0                 House Plants
# 1               Outdoor Living
# 2           Bedroom Decorating
# 3   Christmas Decoration Ideas
# 4                     Holidays
# 5                     Painting
# 6                     Painting
# 7                   Decorating
# 8                   Decorating
# 9                   Decorating
# 10                  Decorating
# 11                  Decorating
# 12                  Decorating
# 13                  Decorating
# 14                  Decorating
#
#                                                  Link  \
# 0   https://www.realsimple.com/home-organizing/gar...
# 1   https://www.realsimple.com/home-organizing/dec...
# 2   https://www.realsimple.com/home-organizing/dec...
# 3   https://www.realsimple.com/home-organizing/dec...
# 4   https://www.realsimple.com/home-organizing/dec...
# 5   https://www.realsimple.com/home-organizing/dec...
# 6   https://www.realsimple.com/home-organizing/dec...
# 7   https://www.realsimple.com/home-organizing/dec...
# 8   https://www.realsimple.com/home-organizing/dec...
# 9   https://www.realsimple.com/home-organizing/dec...
# 10  https://www.realsimple.com/home-organizing/dec...
# 11  https://www.realsimple.com/home-organizing/dec...
# 12  https://www.realsimple.com/home-organizing/dec...
# 13  https://www.realsimple.com/home-organizing/dec...
# 14  https://www.realsimple.com/home-organizing/dec...
#
#                                                 Title  \
# 0   The Best Plant Shelf Ideas to Keep Your Plant ...
# 1   Create a Warm Welcome With Small Front Porch D...
# 2   The 10 Best Cooling Sheets for a Sweat-Free Ni...
# 3   Forget Christmas Tree Skirts—Tree Collars Are ...
# 4   Etsy Predicts These Will Be the Hottest Holida...
# 5   We Can Officially Say These Are the Top Paint ...
# 6   Paint Your Home Happy: Farrow & Ball's New Pai...
# 7   Space of the Week: Two Lawyers Get a Moody Hom...
# 8   5 Stunning Paint Colors Spotted in the Real Si...
# 9   Shop Every Single Room in the 2022 Real Simple...
# 10  3 Secrets to Decorating a Room With Personalit...
# 11     6 Clever Items Spotted in the Real Simple Home
# 12  Coastal Decor Is Trending—Here's How to Nail B...
# 13               6 Top Home Decor Trends of Fall 2022
# 14  This Checkered Area Rug Is One of My Favorite ...
#
#                                            Image_Link
# 0   https://www.realsimple.com/thmb/czI32_i_6UKLr2...
# 1   https://www.realsimple.com/thmb/87689cG2ofLLYR...
# 2   https://www.realsimple.com/thmb/tZx1ZonOL84XRm...
# 3   https://www.realsimple.com/thmb/NsJNucu8UwssCN...
# 4   https://www.realsimple.com/thmb/ycba9S3erK9_rU...
# 5   https://www.realsimple.com/thmb/xkddktLoClr1zq...
# 6   https://www.realsimple.com/thmb/ZyAIRXDPxLcj67...
# 7   https://www.realsimple.com/thmb/uC0YMVqs8b98D6...
# 8   https://www.realsimple.com/thmb/g2yqdZJGuvRsaj...
# 9   https://www.realsimple.com/thmb/yi92iOo1ek1Wdo...
# 10  https://www.realsimple.com/thmb/3jE1hszxIWb57X...
# 11  https://www.realsimple.com/thmb/cleTzfQHA7vrfD...
# 12  https://www.realsimple.com/thmb/8Iq8LJaMsB8HBm...
# 13  https://www.realsimple.com/thmb/QW5RGfNwBgb9FL...
# 14  https://www.realsimple.com/thmb/1IFaGj7-JoxmUT...

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_Q8Nb6XkPh9ZdZnhkYCZL7BgKB5ZZF531g2xb")

# Prepare the actor input
run_input = {
    "maxRequestsPerCrawl": 100,
    "extendOutputFunction": """async ({ data, item, product, images, fns, name, request, variants, context, customData, input, Apify }) => {
  return item;
}""",
    "extendScraperFunction": """async ({ fns, customData, Apify, label }) => {
 
}""",
    "customData": {},
    "maxConcurrency": 100,
    "maxRequestRetries": 3,
}

# Run the actor and wait for it to finish
run = client.actor("mshopik/dania-furniture-scraper").call(run_input=run_input)
list1=[]
# Fetch and print actor results from the run's dataset (if there are any)
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    list1.append(item)

# %%
df1=pd.DataFrame(list1)

# %%
df1
# Out:
#                                                    url               color  \
# 0    https://daniafurniture.com/products/lightsome-...          Dark Brown
# 1    https://daniafurniture.com/products/kinetic-cu...          Dark Brown
# 2    https://daniafurniture.com/products/moose-wood...               Brown
# 3    https://daniafurniture.com/products/vagamo-14-...         Silver Leaf
# 4    https://daniafurniture.com/products/moose-wood...               Brown
# ..                                                 ...                 ...
# 183  https://daniafurniture.com/products/color-bloc...        Navy/Natural
# 184  https://daniafurniture.com/products/mod-colorb...               Multi
# 185  https://daniafurniture.com/products/viktor-wal...  Black Satin-Nickel
# 186  https://daniafurniture.com/products/woven-kant...         Beige/Multi
# 187  https://daniafurniture.com/products/woven-kant...         Beige/Multi
#
#        size material display_name                                title  \
# 0      None     None         None                  Lightsome Sculpture
# 1      None     None         None            Kinetic Current Sculpture
# 2     Small     None         None      Moose Wooden Decoration - Brown
# 3      None     None         None                      Vagamo 14" Vase
# 4    Medium     None         None      Moose Wooden Decoration - Brown
# ..      ...      ...          ...                                  ...
# 183    None     None         None              Color Block Coaster Set
# 184    None     None         None                  Mod Colorblock Tray
# 185    None     None         None                    Viktor Wall Clock
# 186    None     None         None  Woven Kantha Duvet Cover + Sham Set
# 187    None     None         None  Woven Kantha Duvet Cover + Sham Set
#
#                 id                                        description  \
# 0    2190278131815  Bring movement and warmth to your home with th...
# 1    2190278164583  The Kinetic Current Sculpture is a modern piec...
# 2    3942147326055  The Wooden Moose Decoration is ideal for the h...
# 3    2229389164647  The Vagamo Vase is lightweight yet durable, wi...
# 4    3942147326055  The Wooden Moose Decoration is ideal for the h...
# ..             ...                                                ...
# 183  6660329799783  The Color Block Coaster Set does double duty a...
# 184  6660329898087  The Mod Colorblock Tray does double duty as bo...
# 185     9107803408  A good wall clock is the sign of an organized ...
# 186  6638768029799  The Woven Kantha Duvet Set features a detailed...
# 187  6638768029799  The Woven Kantha Duvet Set features a detailed...
#
#                    sku  availability  price currency           product_type  \
# 0          F27*D392H-6  out of stock  649.0      USD  ACC_Decorative Object
# 1           F27*D806-2  out of stock  349.0      USD  ACC_Decorative Object
# 2       M52*BSMZ0009B2  out of stock    5.0      USD  ACC_Decorative Object
# 3       C57*6216-14/SV  out of stock   49.0      USD  ACC_Decorative Object
# 4       M52*BSMZ0009B1  out of stock    9.0      USD  ACC_Decorative Object
# ..                 ...           ...    ...      ...                    ...
# 183     C57*SQ26-21/BU  out of stock   19.0      USD       ACC_Accesssories
# 184  C57*HE03-21/MULTI  out of stock   45.0      USD       ACC_Accesssories
# 185         H14*625403  out of stock  239.0      USD              ACC_Clock
# 186   M50*MM20-403-F/Q  out of stock  179.0      USD            ACC_Bedding
# 187     M50*MM20-403-K  out of stock  199.0      USD            ACC_Bedding
#
#                                            images_urls brand video_urls  \
# 0    [https://cdn.shopify.com/s/files/1/1920/4697/p...   F27         []
# 1    [https://cdn.shopify.com/s/files/1/1920/4697/p...   F27         []
# 2    [https://cdn.shopify.com/s/files/1/1920/4697/p...   M52         []
# 3    [https://cdn.shopify.com/s/files/1/1920/4697/p...   C57         []
# 4    [https://cdn.shopify.com/s/files/1/1920/4697/p...   M52         []
# ..                                                 ...   ...        ...
# 183  [https://cdn.shopify.com/s/files/1/1920/4697/p...   C57         []
# 184  [https://cdn.shopify.com/s/files/1/1920/4697/p...   C57         []
# 185  [https://cdn.shopify.com/s/files/1/1920/4697/p...   H14         []
# 186  [https://cdn.shopify.com/s/files/1/1920/4697/p...   M50         []
# 187  [https://cdn.shopify.com/s/files/1/1920/4697/p...   M50         []
#
#                    created_at                updated_at  \
# 0    2019-04-15T20:38:01.000Z  2022-09-15T18:08:15.000Z
# 1    2019-04-15T20:38:03.000Z  2022-09-13T18:42:35.000Z
# 2    2019-07-17T18:08:12.000Z  2022-09-12T18:10:46.000Z
# 3    2019-05-08T19:49:41.000Z  2022-09-09T22:24:22.000Z
# 4    2019-07-17T18:08:12.000Z  2022-09-12T18:10:46.000Z
# ..                        ...                       ...
# 183  2022-05-12T18:40:38.000Z  2022-09-15T22:10:54.000Z
# 184  2022-05-12T18:40:48.000Z  2022-09-16T15:13:20.000Z
# 185  2017-05-04T23:26:19.000Z  2022-09-16T16:08:35.000Z
# 186  2022-02-08T19:33:31.000Z  2022-09-14T15:13:35.000Z
# 187  2022-02-08T19:33:31.000Z  2022-09-14T15:13:35.000Z
#
#                  published_at  \
# 0    2020-02-13T19:16:18.000Z
# 1    2020-03-10T19:43:30.000Z
# 2    2019-10-29T16:35:19.000Z
# 3    2019-06-04T23:13:48.000Z
# 4    2019-10-29T16:35:19.000Z
# ..                        ...
# 183  2022-05-12T21:55:10.000Z
# 184  2022-05-12T21:22:27.000Z
# 185  2017-05-04T23:26:19.000Z
# 186  2022-05-10T19:43:20.000Z
# 187  2022-05-10T19:43:20.000Z
#
#                                             additional
# 0    {'variant_attributes': 'Color: Dark Brown', 'v...
# 1    {'variant_attributes': 'Color: Dark Brown', 'v...
# 2    {'variant_attributes': 'Color: Brown / Size: S...
# 3    {'variant_attributes': 'Color: Silver Leaf', '...
# 4    {'variant_attributes': 'Color: Brown / Size: M...
# ..                                                 ...
# 183  {'variant_attributes': 'Color: Navy/Natural', ...
# 184  {'variant_attributes': 'Color: Multi', 'varian...
# 185  {'variant_attributes': 'color: Black Satin-Nic...
# 186  {'variant_attributes': 'Color: Beige/Multi / S...
# 187  {'variant_attributes': 'Color: Beige/Multi / S...
#
# [188 rows x 20 columns]

# %%
df1=df1[['url','color','size','title','id','description','price','currency','product_type','images_urls','additional']]

# %%
df1
# Out:
#                                                    url               color  \
# 0    https://daniafurniture.com/products/lightsome-...          Dark Brown
# 1    https://daniafurniture.com/products/kinetic-cu...          Dark Brown
# 2    https://daniafurniture.com/products/moose-wood...               Brown
# 3    https://daniafurniture.com/products/vagamo-14-...         Silver Leaf
# 4    https://daniafurniture.com/products/moose-wood...               Brown
# ..                                                 ...                 ...
# 183  https://daniafurniture.com/products/color-bloc...        Navy/Natural
# 184  https://daniafurniture.com/products/mod-colorb...               Multi
# 185  https://daniafurniture.com/products/viktor-wal...  Black Satin-Nickel
# 186  https://daniafurniture.com/products/woven-kant...         Beige/Multi
# 187  https://daniafurniture.com/products/woven-kant...         Beige/Multi
#
#        size                                title             id  \
# 0      None                  Lightsome Sculpture  2190278131815
# 1      None            Kinetic Current Sculpture  2190278164583
# 2     Small      Moose Wooden Decoration - Brown  3942147326055
# 3      None                      Vagamo 14" Vase  2229389164647
# 4    Medium      Moose Wooden Decoration - Brown  3942147326055
# ..      ...                                  ...            ...
# 183    None              Color Block Coaster Set  6660329799783
# 184    None                  Mod Colorblock Tray  6660329898087
# 185    None                    Viktor Wall Clock     9107803408
# 186    None  Woven Kantha Duvet Cover + Sham Set  6638768029799
# 187    None  Woven Kantha Duvet Cover + Sham Set  6638768029799
#
#                                            description  price currency  \
# 0    Bring movement and warmth to your home with th...  649.0      USD
# 1    The Kinetic Current Sculpture is a modern piec...  349.0      USD
# 2    The Wooden Moose Decoration is ideal for the h...    5.0      USD
# 3    The Vagamo Vase is lightweight yet durable, wi...   49.0      USD
# 4    The Wooden Moose Decoration is ideal for the h...    9.0      USD
# ..                                                 ...    ...      ...
# 183  The Color Block Coaster Set does double duty a...   19.0      USD
# 184  The Mod Colorblock Tray does double duty as bo...   45.0      USD
# 185  A good wall clock is the sign of an organized ...  239.0      USD
# 186  The Woven Kantha Duvet Set features a detailed...  179.0      USD
# 187  The Woven Kantha Duvet Set features a detailed...  199.0      USD
#
#               product_type                                        images_urls  \
# 0    ACC_Decorative Object  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 1    ACC_Decorative Object  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 2    ACC_Decorative Object  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 3    ACC_Decorative Object  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 4    ACC_Decorative Object  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# ..                     ...                                                ...
# 183       ACC_Accesssories  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 184       ACC_Accesssories  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 185              ACC_Clock  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 186            ACC_Bedding  [https://cdn.shopify.com/s/files/1/1920/4697/p...
# 187            ACC_Bedding  [https://cdn.shopify.com/s/files/1/1920/4697/p...
#
#                                             additional
# 0    {'variant_attributes': 'Color: Dark Brown', 'v...
# 1    {'variant_attributes': 'Color: Dark Brown', 'v...
# 2    {'variant_attributes': 'Color: Brown / Size: S...
# 3    {'variant_attributes': 'Color: Silver Leaf', '...
# 4    {'variant_attributes': 'Color: Brown / Size: M...
# ..                                                 ...
# 183  {'variant_attributes': 'Color: Navy/Natural', ...
# 184  {'variant_attributes': 'Color: Multi', 'varian...
# 185  {'variant_attributes': 'color: Black Satin-Nic...
# 186  {'variant_attributes': 'Color: Beige/Multi / S...
# 187  {'variant_attributes': 'Color: Beige/Multi / S...
#
# [188 rows x 11 columns]

# %%
df1.to_excel("output.xlsx")

# %%
df.to_excel("output1.xlsx")
